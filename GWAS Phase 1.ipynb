# %% [markdown]
# <img src="https://hail.is/docs/devel/hail-logo-cropped.png" width= "150px">

# %% [markdown]
# # Hail's overview
#
# ### https://hail.is/docs/devel/tutorials-landing.html

# %% [markdown]
# ### PHASE 1 - 1k Genomes Project
#
# VCFs can be find in the public google bucket :
# https://console.cloud.google.com/storage/browser/genomics-public-data/1000-genomes/

# %% [markdown]
# ### Hail environment and Python packages

# %%
import hail as hl
import hail.expr.aggregators as agg
hl.init()
# Out:
# /opt/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /opt/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# Running on Apache Spark version 2.2.1
# SparkUI available at http://10.142.0.5:4040
# Welcome to
#      __  __     <>__
#     / /_/ /__  __/ /
#    / __  / _ `/ / /
#   /_/ /_/\_,_/_/_/   version devel-98f4d6a179b4
# NOTE: This is a beta version. Interfaces may change
#   during the beta period. We recommend pulling
#   the latest changes weekly.

# %%
import numpy as np
import pandas as pd
from collections import Counter
from math import log, isnan
from pprint import pprint
from bokeh.io import show, output_notebook
from bokeh.plotting import figure
from bokeh.layouts import gridplot
from bokeh.models import Span
output_notebook()
import plotly
import time
import gcsfs
import csv
from bokeh.io import output_notebook, push_notebook, show
import seaborn as sb
import random
import gcsfs
fs = gcsfs.GCSFileSystem(project='avl-hail-ines')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="73f95e6b-ae73-42d7-82a0-150b14d74371">Loading BokehJS ...</span>
#     </div>
# No module named 'dask'

# %% [markdown]
# ### Import the Matrix Table Files

# %%
# Phase 1 - 1k Genome Project
mt = hl.read_matrix_table("gs://1k-genome/1000-genomes/VDS-of-all/ALL.chr.integrated_phase1_v3.20101123.snps_indels_svs.genotypes.mt")
print('MT size: ', mt.count())
# Out:
# MT size:  (39706715, 1092)

# %% [markdown]
# The `cache` is used to optimize some of the downstream operations.

# %%
mt = hl.variant_qc(mt).cache()

# %%
mt.describe()
# Out:
# ----------------------------------------
# Global fields:
#     None
# ----------------------------------------
# Column fields:
#     's': str
# ----------------------------------------
# Row fields:
#     'locus': locus<GRCh37>
#     'alleles': array<str>
#     'rsid': str
#     'qual': float64
#     'filters': set<str>
#     'info': struct {
#         LDAF: float64,
#         AVGPOST: float64,
#         RSQ: float64,
#         ERATE: float64,
#         THETA: float64,
#         CIEND: array<int32>,
#         CIPOS: array<int32>,
#         END: int32,
#         HOMLEN: array<int32>,
#         HOMSEQ: array<str>,
#         SVLEN: int32,
#         SVTYPE: str,
#         AC: array<int32>,
#         AN: int32,
#         AA: str,
#         AF: array<float64>,
#         AMR_AF: float64,
#         ASN_AF: float64,
#         AFR_AF: float64,
#         EUR_AF: float64,
#         VT: str,
#         SNPSOURCE: array<str>
#     }
#     'variant_qc': struct {
#         AC: array<int32>,
#         AF: array<float64>,
#         AN: int32,
#         homozygote_count: array<int32>,
#         n_called: int64,
#         n_not_called: int64,
#         call_rate: float32,
#         n_het: int64,
#         n_non_ref: int64,
#         het_freq_hwe: float64,
#         p_value_hwe: float64
#     }
# ----------------------------------------
# Entry fields:
#     'GT': call
#     'DS': float64
#     'GL': array<float64>
#     'PL': array<int32>
# ----------------------------------------
# Column key: ['s']
# Row key: ['locus', 'alleles']
# Partition key: ['locus']
# ----------------------------------------

# %%
hl.summarize_variants(mt)
# Out:
# ==============================
# Number of variants: 39706715
# ==============================
# Alleles per variant
# -------------------
#   2 alleles: 39706715 variants
# ==============================
# Variants per contig
# -------------------
#    1: 3007196 variants
#    2: 3307592 variants
#    3: 2763454 variants
#    4: 2736765 variants
#    5: 2530217 variants
#    6: 2424425 variants
#    7: 2215231 variants
#    8: 2183839 variants
#    9: 1652388 variants
#   10: 1882663 variants
#   11: 1894908 variants
#   12: 1828006 variants
#   13: 1373000 variants
#   14: 1258254 variants
#   15: 1130554 variants
#   16: 1210619 variants
#   17: 1046733 variants
#   18: 1088820 variants
#   19: 816115 variants
#   20: 855166 variants
#   21: 518965 variants
#   22: 494328 variants
#    X: 1487477 variants
# ==============================
# Allele type distribution
# ------------------------
#         SNP: 38248779 alternate alleles
#    Deletion: 872267 alternate alleles
#   Insertion: 577895 alternate alleles
#    Symbolic: 5488 alternate alleles
#     Complex: 2286 alternate alleles
# ==============================

# %%
mt.entry.take(5)
# Out:
# [Struct(GT=0|0, DS=0.2, GL=[-0.18, -0.47, -2.42], PL=None),
#  Struct(GT=0|0, DS=0.15, GL=[-0.24, -0.44, -1.16], PL=None),
#  Struct(GT=0|0, DS=0.15, GL=[-0.15, -0.54, -3.12], PL=None),
#  Struct(GT=0|1, DS=0.6, GL=[-0.48, -0.48, -0.48], PL=None),
#  Struct(GT=0|0, DS=0.55, GL=[-0.48, -0.48, -0.48], PL=None)]

# %%
mt.entry.show()
# Out:
# +---------------+------------+---------+------+-------------+---------------------+
# | locus         | alleles    | s       | GT   |          DS | GL                  |
# +---------------+------------+---------+------+-------------+---------------------+
# | locus<GRCh37> | array<str> | str     | call |     float64 | array<float64>      |
# +---------------+------------+---------+------+-------------+---------------------+
# | 1:10583       | ["G","A"]  | HG00096 | 0|0  | 2.00000e-01 | [-0.18,-0.47,-2.42] |
# | 1:10583       | ["G","A"]  | HG00097 | 0|0  | 1.50000e-01 | [-0.24,-0.44,-1.16] |
# | 1:10583       | ["G","A"]  | HG00099 | 0|0  | 1.50000e-01 | [-0.15,-0.54,-3.12] |
# | 1:10583       | ["G","A"]  | HG00100 | 0|1  | 6.00000e-01 | [-0.48,-0.48,-0.48] |
# | 1:10583       | ["G","A"]  | HG00101 | 0|0  | 5.50000e-01 | [-0.48,-0.48,-0.48] |
# | 1:10583       | ["G","A"]  | HG00102 | 0|1  | 9.50000e-01 | [-1.92,-0.01,-2.5]  |
# | 1:10583       | ["G","A"]  | HG00103 | 0|0  | 5.00000e-02 | [-0.05,-0.93,-5.0]  |
# | 1:10583       | ["G","A"]  | HG00104 | 0|0  | 1.00000e-01 | [-0.11,-0.66,-4.22] |
# | 1:10583       | ["G","A"]  | HG00106 | 0|1  | 5.50000e-01 | [-0.28,-0.43,-0.96] |
# | 1:10583       | ["G","A"]  | HG00108 | 0|0  | 4.50000e-01 | [-0.48,-0.48,-0.48] |
# +---------------+------------+---------+------+-------------+---------------------+
#
# +--------------+
# | PL           |
# +--------------+
# | array<int32> |
# +--------------+
# | null         |
# | null         |
# | null         |
# | null         |
# | null         |
# | null         |
# | null         |
# | null         |
# | null         |
# | null         |
# +--------------+
# showing top 10 rows

# %%
mt.rows().select().show(5)
# Out:
# +---------------+------------+
# | locus         | alleles    |
# +---------------+------------+
# | locus<GRCh37> | array<str> |
# +---------------+------------+
# | 1:10583       | ["G","A"]  |
# | 1:10611       | ["C","G"]  |
# | 1:13302       | ["C","T"]  |
# | 1:13327       | ["G","C"]  |
# | 1:13957       | ["TC","T"] |
# +---------------+------------+
# showing top 5 rows

# %% [markdown]
# ### Annotation file : encode the label Super_population

# %%
# Import Annotation File as a hail.Table
table = (hl.import_table('gs://1k-genome/1000-genomes/other/sample_info/sample_info.csv', delimiter=',', missing='', quote='"').key_by('Sample'))
table.describe()
# Out:
# ----------------------------------------
# Global fields:
#     None
# ----------------------------------------
# Row fields:
#     'Sample': str
#     'Family_ID': str
#     'Population': str
#     'Population_Description': str
#     'Gender': str
#     'Relationship': str
#     'Unexpected_Parent_Child': str
#     'Non_Paternity': str
#     'Siblings': str
#     'Grandparents': str
#     'Avuncular': str
#     'Half_Siblings': str
#     'Unknown_Second_Order': str
#     'Third_Order': str
#     'In_Low_Coverage_Pilot': str
#     'LC_Pilot_Platforms': str
#     'LC_Pilot_Centers': str
#     'In_High_Coverage_Pilot': str
#     'HC_Pilot_Platforms': str
#     'HC_Pilot_Centers': str
#     'In_Exon_Targetted_Pilot': str
#     'ET_Pilot_Platforms': str
#     'ET_Pilot_Centers': str
#     'Has_Sequence_in_Phase1': str
#     'Phase1_LC_Platform': str
#     'Phase1_LC_Centers': str
#     'Phase1_E_Platform': str
#     'Phase1_E_Centers': str
#     'In_Phase1_Integrated_Variant_Set': str
#     'Has_Phase1_chrY_SNPS': str
#     'Has_phase1_chrY_Deletions': str
#     'Has_phase1_chrMT_SNPs': str
#     'Main_project_LC_Centers': str
#     'Main_project_LC_platform': str
#     'Total_LC_Sequence': str
#     'LC_Non_Duplicated_Aligned_Coverage': str
#     'Main_Project_E_Centers': str
#     'Main_Project_E_Platform': str
#     'Total_Exome_Sequence': str
#     'X_Targets_Covered_to_20x_or_greater': str
#     'VerifyBam_E_Omni_Free': str
#     'VerifyBam_E_Affy_Free': str
#     'VerifyBam_E_Omni_Chip': str
#     'VerifyBam_E_Affy_Chip': str
#     'VerifyBam_LC_Omni_Free': str
#     'VerifyBam_LC_Affy_Free': str
#     'VerifyBam_LC_Omni_Chip': str
#     'VerifyBam_LC_Affy_Chip': str
#     'LC_Indel_Ratio': str
#     'E_Indel_Ratio': str
#     'LC_Passed_QC': str
#     'E_Passed_QC': str
#     'In_Final_Phase_Variant_Calling': str
#     'Has_Omni_Genotypes': str
#     'Has_Axiom_Genotypes': str
#     'Has_Affy_6_0_Genotypes': str
#     'Has_Exome_LOF_Genotypes': str
#     'EBV_Coverage': str
#     'DNA_Source_from_Coriell': str
#     'Has_Sequence_from_Blood_in_Index': str
#     'Super_Population': str
#     'Super_Population_Description': str
# ----------------------------------------
# Key: ['Sample']
# ----------------------------------------
# 2018-08-07 12:40:43 Hail: INFO: Reading table with no type imputation
#   Loading column 'Sample' as type 'str' (type not specified)
#   Loading column 'Family_ID' as type 'str' (type not specified)
#   Loading column 'Population' as type 'str' (type not specified)
#   Loading column 'Population_Description' as type 'str' (type not specified)
#   Loading column 'Gender' as type 'str' (type not specified)
#   Loading column 'Relationship' as type 'str' (type not specified)
#   Loading column 'Unexpected_Parent_Child' as type 'str' (type not specified)
#   Loading column 'Non_Paternity' as type 'str' (type not specified)
#   Loading column 'Siblings' as type 'str' (type not specified)
#   Loading column 'Grandparents' as type 'str' (type not specified)
#   Loading column 'Avuncular' as type 'str' (type not specified)
#   Loading column 'Half_Siblings' as type 'str' (type not specified)
#   Loading column 'Unknown_Second_Order' as type 'str' (type not specified)
#   Loading column 'Third_Order' as type 'str' (type not specified)
#   Loading column 'In_Low_Coverage_Pilot' as type 'str' (type not specified)
#   Loading column 'LC_Pilot_Platforms' as type 'str' (type not specified)
#   Loading column 'LC_Pilot_Centers' as type 'str' (type not specified)
#   Loading column 'In_High_Coverage_Pilot' as type 'str' (type not specified)
#   Loading column 'HC_Pilot_Platforms' as type 'str' (type not specified)
#   Loading column 'HC_Pilot_Centers' as type 'str' (type not specified)
#   Loading column 'In_Exon_Targetted_Pilot' as type 'str' (type not specified)
#   Loading column 'ET_Pilot_Platforms' as type 'str' (type not specified)
#   Loading column 'ET_Pilot_Centers' as type 'str' (type not specified)
#   Loading column 'Has_Sequence_in_Phase1' as type 'str' (type not specified)
#   Loading column 'Phase1_LC_Platform' as type 'str' (type not specified)
#   Loading column 'Phase1_LC_Centers' as type 'str' (type not specified)
#   Loading column 'Phase1_E_Platform' as type 'str' (type not specified)
#   Loading column 'Phase1_E_Centers' as type 'str' (type not specified)
#   Loading column 'In_Phase1_Integrated_Variant_Set' as type 'str' (type not specified)
#   Loading column 'Has_Phase1_chrY_SNPS' as type 'str' (type not specified)
#   Loading column 'Has_phase1_chrY_Deletions' as type 'str' (type not specified)
#   Loading column 'Has_phase1_chrMT_SNPs' as type 'str' (type not specified)
#   Loading column 'Main_project_LC_Centers' as type 'str' (type not specified)
#   Loading column 'Main_project_LC_platform' as type 'str' (type not specified)
#   Loading column 'Total_LC_Sequence' as type 'str' (type not specified)
#   Loading column 'LC_Non_Duplicated_Aligned_Coverage' as type 'str' (type not specified)
#   Loading column 'Main_Project_E_Centers' as type 'str' (type not specified)
#   Loading column 'Main_Project_E_Platform' as type 'str' (type not specified)
#   Loading column 'Total_Exome_Sequence' as type 'str' (type not specified)
#   Loading column 'X_Targets_Covered_to_20x_or_greater' as type 'str' (type not specified)
#   Loading column 'VerifyBam_E_Omni_Free' as type 'str' (type not specified)
#   Loading column 'VerifyBam_E_Affy_Free' as type 'str' (type not specified)
#   Loading column 'VerifyBam_E_Omni_Chip' as type 'str' (type not specified)
#   Loading column 'VerifyBam_E_Affy_Chip' as type 'str' (type not specified)
#   Loading column 'VerifyBam_LC_Omni_Free' as type 'str' (type not specified)
#   Loading column 'VerifyBam_LC_Affy_Free' as type 'str' (type not specified)
#   Loading column 'VerifyBam_LC_Omni_Chip' as type 'str' (type not specified)
#   Loading column 'VerifyBam_LC_Affy_Chip' as type 'str' (type not specified)
#   Loading column 'LC_Indel_Ratio' as type 'str' (type not specified)
#   Loading column 'E_Indel_Ratio' as type 'str' (type not specified)
#   Loading column 'LC_Passed_QC' as type 'str' (type not specified)
#   Loading column 'E_Passed_QC' as type 'str' (type not specified)
#   Loading column 'In_Final_Phase_Variant_Calling' as type 'str' (type not specified)
#   Loading column 'Has_Omni_Genotypes' as type 'str' (type not specified)
#   Loading column 'Has_Axiom_Genotypes' as type 'str' (type not specified)
#   Loading column 'Has_Affy_6_0_Genotypes' as type 'str' (type not specified)
#   Loading column 'Has_Exome_LOF_Genotypes' as type 'str' (type not specified)
#   Loading column 'EBV_Coverage' as type 'str' (type not specified)
#   Loading column 'DNA_Source_from_Coriell' as type 'str' (type not specified)
#   Loading column 'Has_Sequence_from_Blood_in_Index' as type 'str' (type not specified)
#   Loading column 'Super_Population' as type 'str' (type not specified)
#   Loading column 'Super_Population_Description' as type 'str' (type not specified)

# %%
# Import Annotation File as a pandas.DataFrame
with fs.open('1k-genome/1000-genomes/other/sample_info/sample_info.csv',"rt") as f:
    data = pd.read_csv(f, na_values = str, header = 0)
print ('Annotation File Size : ', data.shape)
# Out:
# Annotation File Size :  (3500, 62)

# %%
data = data.astype(str)
data[['In_Low_Coverage_Pilot', 'In_High_Coverage_Pilot', 'In_Exon_Targetted_Pilot', 'Has_Sequence_in_Phase1', 
      'In_Phase1_Integrated_Variant_Set',"Has_Phase1_chrY_SNPS",
        'Has_phase1_chrY_Deletions','Has_phase1_chrMT_SNPs', 'Total_LC_Sequence','LC_Non_Duplicated_Aligned_Coverage', 'Total_Exome_Sequence',
        'X_Targets_Covered_to_20x_or_greater','VerifyBam_E_Omni_Free','VerifyBam_E_Affy_Free','VerifyBam_E_Omni_Chip','VerifyBam_E_Affy_Chip','VerifyBam_LC_Omni_Free',                 
        'VerifyBam_LC_Affy_Free', 'VerifyBam_LC_Omni_Chip','VerifyBam_LC_Affy_Chip','LC_Indel_Ratio','E_Indel_Ratio',                          
        'LC_Passed_QC', 'E_Passed_QC', 'In_Final_Phase_Variant_Calling','Has_Omni_Genotypes','Has_Axiom_Genotypes','Has_Affy_6_0_Genotypes',                 
        'Has_Exome_LOF_Genotypes','EBV_Coverage', 
        'Has_Sequence_from_Blood_in_Index' ]] = data[['In_Low_Coverage_Pilot', 'In_High_Coverage_Pilot', 'In_Exon_Targetted_Pilot', 'Has_Sequence_in_Phase1', 'In_Phase1_Integrated_Variant_Set',"Has_Phase1_chrY_SNPS",
        'Has_phase1_chrY_Deletions','Has_phase1_chrMT_SNPs', 'Total_LC_Sequence','LC_Non_Duplicated_Aligned_Coverage', 'Total_Exome_Sequence',
        'X_Targets_Covered_to_20x_or_greater','VerifyBam_E_Omni_Free','VerifyBam_E_Affy_Free','VerifyBam_E_Omni_Chip','VerifyBam_E_Affy_Chip','VerifyBam_LC_Omni_Free',                 
        'VerifyBam_LC_Affy_Free',                 
        'VerifyBam_LC_Omni_Chip',                 
        'VerifyBam_LC_Affy_Chip',                 
        'LC_Indel_Ratio',                         
        'E_Indel_Ratio',                          
        'LC_Passed_QC',                           
        'E_Passed_QC',                            
        'In_Final_Phase_Variant_Calling',         
        'Has_Omni_Genotypes',                     
        'Has_Axiom_Genotypes',                    
        'Has_Affy_6_0_Genotypes',                 
        'Has_Exome_LOF_Genotypes',                
        'EBV_Coverage', 'Has_Sequence_from_Blood_in_Index' ]].astype(float)

# %% [markdown]
# We use the *LabelEncoder* method  from `scikit-learn` to encode the label Super Population which contains 4 groups for phase 1.

# %%
from sklearn.preprocessing import LabelEncoder
key = data['Super_Population'].values

#create Label encoder for Super_Population
le = LabelEncoder()
le.fit(['SAS', 'EUR', 'AFR', 'AMR', 'EAS'])

#append to the Dataframe
data["Super_Population_Classification"] = pd.Series(le.transform(key), index=data.index)

# %% [markdown]
# ### Annotate the MT file

# %%
#Add the label Super_Population_Classification 
table1 = hl.Table.to_pandas(table)
table1["Super_Population_Classification"] = pd.Series(le.transform(key).astype(float)) 
table1 = hl.Table.from_pandas(table1).key_by('Sample')
# Out:
# 2018-08-07 12:40:44 Hail: INFO: Coerced sorted dataset

# %% [markdown]
# We use the `annotate_cols` method to join the table with the MatrixTable containing our dataset.

# %%
#Annotate the MF file
mt = mt.annotate_cols(**table1[mt.s])
# Out:
# 2018-08-07 12:40:53 Hail: INFO: Coerced almost-sorted dataset
# 2018-08-07 12:41:17 Hail: INFO: Ordering unsorted dataset with network shuffle

# %% [markdown]
# ### Query functions and the Hail Expression Language

# %% [markdown]
# The `aggregate` method can be used to aggregate over rows of the table.
# `counter` is an aggregation function that counts the number of occurrences of each unique element. We can use this to pull out the population distribution by passing in a Hail Expression for the field that we want to count by.

# %%
pprint(table1.aggregate(agg.counter(table1.Super_Population)))
# Out:
# 2018-08-07 12:41:33 Hail: INFO: Coerced almost-sorted dataset
# 2018-08-07 12:41:46 Hail: INFO: Ordering unsorted dataset with network shuffle
# {'AFR': 1018, 'AMR': 535, 'EAS': 617, 'EUR': 669, 'SAS': 661}

# %%
snp_counts = mt.aggregate_rows(agg.counter(hl.Struct(ref=mt.alleles[0], alt=mt.alleles[1])))

# %% [markdown]
# We can list the counts in descending order using Python’s Counter class.

# %%
from collections import Counter
counts = Counter(snp_counts)
counts.most_common()
# Out:
# [(Struct(ref=G, alt=A), 7768570),
#  (Struct(ref=C, alt=T), 7730953),
#  (Struct(ref=A, alt=G), 5318273),
#  (Struct(ref=T, alt=C), 5312221),
#  (Struct(ref=C, alt=A), 1772424),
#  (Struct(ref=G, alt=T), 1758628),
#  (Struct(ref=C, alt=G), 1633912),
#  (Struct(ref=G, alt=C), 1624685),
#  (Struct(ref=A, alt=C), 1354055),
#  (Struct(ref=T, alt=G), 1350151),
#  (Struct(ref=T, alt=A), 1313500),
#  (Struct(ref=A, alt=T), 1311407),
#  (Struct(ref=A, alt=AT), 63401),
#  (Struct(ref=T, alt=TA), 58720),
#  (Struct(ref=AT, alt=A), 53873),
#  (Struct(ref=TA, alt=T), 49001),
#  (Struct(ref=C, alt=CA), 45240),
#  (Struct(ref=C, alt=CT), 41699),
#  (Struct(ref=G, alt=GA), 41038),
#  (Struct(ref=CT, alt=C), 39935),
#  (Struct(ref=TG, alt=T), 37299),
#  (Struct(ref=G, alt=GT), 36619),
#  (Struct(ref=AG, alt=A), 35852),
#  (Struct(ref=CA, alt=C), 35025),
#  (Struct(ref=GA, alt=G), 33063),
#  (Struct(ref=AC, alt=A), 32616),
#  (Struct(ref=TC, alt=T), 30579),
#  (Struct(ref=T, alt=TG), 25565),
#  (Struct(ref=T, alt=TC), 23599),
#  (Struct(ref=GT, alt=G), 22966),
#  (Struct(ref=A, alt=AG), 20299),
#  (Struct(ref=A, alt=AC), 19724),
#  (Struct(ref=GC, alt=G), 16872),
#  (Struct(ref=CAT, alt=C), 16495),
#  (Struct(ref=G, alt=GC), 11477),
#  (Struct(ref=CAG, alt=C), 9354),
#  (Struct(ref=CTT, alt=C), 8568),
#  (Struct(ref=CTG, alt=C), 7393),
#  (Struct(ref=ACT, alt=A), 7369),
#  (Struct(ref=TTC, alt=T), 7325),
#  (Struct(ref=AAG, alt=A), 7156),
#  (Struct(ref=AAT, alt=A), 6782),
#  (Struct(ref=CG, alt=C), 6662),
#  (Struct(ref=AAC, alt=A), 6487),
#  (Struct(ref=TTA, alt=T), 6267),
#  (Struct(ref=C, alt=CAT), 6188),
#  (Struct(ref=TAC, alt=T), 5390),
#  (Struct(ref=CCT, alt=C), 5210),
#  (Struct(ref=C, alt=CG), 5134),
#  (Struct(ref=TAA, alt=T), 4979),
#  (Struct(ref=ATG, alt=A), 4852),
#  (Struct(ref=CAA, alt=C), 4671),
#  (Struct(ref=TTG, alt=T), 4513),
#  (Struct(ref=AAAG, alt=A), 4378),
#  (Struct(ref=GTA, alt=G), 4250),
#  (Struct(ref=T, alt=TTC), 4107),
#  (Struct(ref=G, alt=GTA), 4014),
#  (Struct(ref=T, alt=TTA), 3825),
#  (Struct(ref=CTA, alt=C), 3717),
#  (Struct(ref=TCA, alt=T), 3405),
#  (Struct(ref=A, alt=AAT), 3342),
#  (Struct(ref=T, alt=TAC), 3100),
#  (Struct(ref=A, alt=ATG), 3018),
#  (Struct(ref=C, alt=CTT), 3007),
#  (Struct(ref=AAAAC, alt=A), 2911),
#  (Struct(ref=CCTT, alt=C), 2852),
#  (Struct(ref=TTTC, alt=T), 2820),
#  (Struct(ref=TGA, alt=T), 2753),
#  (Struct(ref=AAAC, alt=A), 2737),
#  (Struct(ref=T, alt=TAA), 2729),
#  (Struct(ref=ATC, alt=A), 2725),
#  (Struct(ref=TCTC, alt=T), 2718),
#  (Struct(ref=CCA, alt=C), 2607),
#  (Struct(ref=T, alt=TTG), 2589),
#  (Struct(ref=GAA, alt=G), 2562),
#  (Struct(ref=GAC, alt=G), 2560),
#  (Struct(ref=C, alt=CAG), 2556),
#  (Struct(ref=TTTTG, alt=T), 2533),
#  (Struct(ref=AAAAG, alt=A), 2513),
#  (Struct(ref=AAAT, alt=A), 2479),
#  (Struct(ref=A, alt=AAC), 2477),
#  (Struct(ref=ATT, alt=A), 2468),
#  (Struct(ref=A, alt=ACT), 2444),
#  (Struct(ref=TTTG, alt=T), 2309),
#  (Struct(ref=AGT, alt=A), 2295),
#  (Struct(ref=GCA, alt=G), 2280),
#  (Struct(ref=TAG, alt=T), 2245),
#  (Struct(ref=C, alt=CTG), 2241),
#  (Struct(ref=GTC, alt=G), 2163),
#  (Struct(ref=C, alt=CAA), 2127),
#  (Struct(ref=TATA, alt=T), 2099),
#  (Struct(ref=C, alt=CTA), 2072),
#  (Struct(ref=TTTTC, alt=T), 2063),
#  (Struct(ref=GAT, alt=G), 2030),
#  (Struct(ref=A, alt=ATT), 2028),
#  (Struct(ref=GGA, alt=G), 1993),
#  (Struct(ref=ATAT, alt=A), 1943),
#  (Struct(ref=A, alt=AAG), 1884),
#  (Struct(ref=CTCTT, alt=C), 1835),
#  (Struct(ref=TTTA, alt=T), 1756),
#  (Struct(ref=CATT, alt=C), 1741),
#  (Struct(ref=GGT, alt=G), 1716),
#  (Struct(ref=AAAAT, alt=A), 1716),
#  (Struct(ref=G, alt=GAT), 1621),
#  (Struct(ref=TAAG, alt=T), 1590),
#  (Struct(ref=TAAC, alt=T), 1550),
#  (Struct(ref=G, alt=GAA), 1528),
#  (Struct(ref=A, alt=<DEL>), 1522),
#  (Struct(ref=T, alt=<DEL>), 1504),
#  (Struct(ref=TATC, alt=T), 1492),
#  (Struct(ref=T, alt=TCA), 1465),
#  (Struct(ref=GAGA, alt=G), 1444),
#  (Struct(ref=T, alt=TTTC), 1394),
#  (Struct(ref=GCT, alt=G), 1382),
#  (Struct(ref=ACTT, alt=A), 1378),
#  (Struct(ref=T, alt=TGA), 1370),
#  (Struct(ref=C, alt=CCT), 1353),
#  (Struct(ref=G, alt=GTT), 1335),
#  (Struct(ref=TTTTA, alt=T), 1305),
#  (Struct(ref=A, alt=ATC), 1291),
#  (Struct(ref=TAAAC, alt=T), 1262),
#  (Struct(ref=G, alt=GTC), 1251),
#  (Struct(ref=GTT, alt=G), 1248),
#  (Struct(ref=G, alt=<DEL>), 1241),
#  (Struct(ref=TTAA, alt=T), 1227),
#  (Struct(ref=C, alt=<DEL>), 1221),
#  (Struct(ref=T, alt=TAG), 1220),
#  (Struct(ref=TGC, alt=T), 1210),
#  (Struct(ref=ATCT, alt=A), 1199),
#  (Struct(ref=AATT, alt=A), 1189),
#  (Struct(ref=A, alt=AGT), 1185),
#  (Struct(ref=CTCT, alt=C), 1174),
#  (Struct(ref=G, alt=GCA), 1173),
#  (Struct(ref=TTCTC, alt=T), 1151),
#  (Struct(ref=G, alt=GAC), 1133),
#  (Struct(ref=CTGTT, alt=C), 1130),
#  (Struct(ref=C, alt=CCA), 1094),
#  (Struct(ref=AAGG, alt=A), 1089),
#  (Struct(ref=AGAG, alt=A), 1080),
#  (Struct(ref=CGT, alt=C), 1076),
#  (Struct(ref=T, alt=TTTG), 1070),
#  (Struct(ref=ATGT, alt=A), 1038),
#  (Struct(ref=CAAT, alt=C), 1032),
#  (Struct(ref=CAAAT, alt=C), 1018),
#  (Struct(ref=ATTC, alt=A), 999),
#  (Struct(ref=T, alt=TGC), 971),
#  (Struct(ref=AGG, alt=A), 967),
#  (Struct(ref=T, alt=TGG), 964),
#  (Struct(ref=CAGA, alt=C), 945),
#  (Struct(ref=T, alt=TCC), 943),
#  (Struct(ref=G, alt=GGT), 926),
#  (Struct(ref=ATTG, alt=A), 925),
#  (Struct(ref=A, alt=AGG), 917),
#  (Struct(ref=ATATT, alt=A), 917),
#  (Struct(ref=G, alt=GGA), 903),
#  (Struct(ref=TGG, alt=T), 900),
#  (Struct(ref=TAAAG, alt=T), 900),
#  (Struct(ref=TTAAA, alt=T), 889),
#  (Struct(ref=GAGAA, alt=G), 881),
#  (Struct(ref=CAAG, alt=C), 870),
#  (Struct(ref=ATAAT, alt=A), 853),
#  (Struct(ref=TGAA, alt=T), 845),
#  (Struct(ref=AAGAG, alt=A), 845),
#  (Struct(ref=A, alt=AAAC), 844),
#  (Struct(ref=CCTTT, alt=C), 843),
#  (Struct(ref=TCC, alt=T), 840),
#  (Struct(ref=CAGG, alt=C), 837),
#  (Struct(ref=T, alt=TTTTC), 835),
#  (Struct(ref=TAGA, alt=T), 834),
#  (Struct(ref=CTTG, alt=C), 822),
#  (Struct(ref=TGAG, alt=T), 821),
#  (Struct(ref=CTTCT, alt=C), 821),
#  (Struct(ref=G, alt=GCT), 809),
#  (Struct(ref=T, alt=TTTA), 806),
#  (Struct(ref=A, alt=AAAAC), 801),
#  (Struct(ref=ACG, alt=A), 798),
#  (Struct(ref=T, alt=TTTTG), 791),
#  (Struct(ref=A, alt=AAAT), 788),
#  (Struct(ref=CTATT, alt=C), 784),
#  (Struct(ref=GTTC, alt=G), 778),
#  (Struct(ref=TAGAC, alt=T), 775),
#  (Struct(ref=TATG, alt=T), 762),
#  (Struct(ref=ACC, alt=A), 760),
#  (Struct(ref=AAAAAG, alt=A), 758),
#  (Struct(ref=CATA, alt=C), 756),
#  (Struct(ref=AATG, alt=A), 755),
#  (Struct(ref=A, alt=ACC), 754),
#  (Struct(ref=CACAT, alt=C), 754),
#  (Struct(ref=TAATA, alt=T), 736),
#  (Struct(ref=A, alt=AAAG), 719),
#  (Struct(ref=GATA, alt=G), 701),
#  (Struct(ref=AGTT, alt=A), 698),
#  (Struct(ref=TATTA, alt=T), 692),
#  (Struct(ref=TAGAG, alt=T), 691),
#  (Struct(ref=ATATG, alt=A), 689),
#  (Struct(ref=C, alt=CGT), 688),
#  (Struct(ref=TTTAA, alt=T), 685),
#  (Struct(ref=CTTA, alt=C), 678),
#  (Struct(ref=GGC, alt=G), 678),
#  (Struct(ref=T, alt=TTTTA), 675),
#  (Struct(ref=GTTA, alt=G), 673),
#  (Struct(ref=GGAA, alt=G), 659),
#  (Struct(ref=ATTTG, alt=A), 657),
#  (Struct(ref=ATATAT, alt=A), 656),
#  (Struct(ref=TCAAA, alt=T), 654),
#  (Struct(ref=CTTTG, alt=C), 652),
#  (Struct(ref=CACA, alt=C), 650),
#  (Struct(ref=ATTAT, alt=A), 648),
#  (Struct(ref=TATAC, alt=T), 644),
#  (Struct(ref=CACTT, alt=C), 640),
#  (Struct(ref=TGTG, alt=T), 631),
#  (Struct(ref=C, alt=CCTT), 630),
#  (Struct(ref=AAATT, alt=A), 626),
#  (Struct(ref=A, alt=AAAAT), 618),
#  (Struct(ref=CTGT, alt=C), 604),
#  (Struct(ref=TAGAA, alt=T), 601),
#  (Struct(ref=TACA, alt=T), 594),
#  (Struct(ref=TAAA, alt=T), 594),
#  (Struct(ref=A, alt=ACG), 593),
#  (Struct(ref=GTGTA, alt=G), 590),
#  (Struct(ref=ACTC, alt=A), 589),
#  (Struct(ref=TACTC, alt=T), 586),
#  (Struct(ref=CAATT, alt=C), 577),
#  (Struct(ref=TTCC, alt=T), 573),
#  (Struct(ref=TATATA, alt=T), 572),
#  (Struct(ref=TAGG, alt=T), 572),
#  (Struct(ref=TAGTC, alt=T), 572),
#  (Struct(ref=CTCTG, alt=C), 570),
#  (Struct(ref=GAAGA, alt=G), 567),
#  (Struct(ref=AGC, alt=A), 562),
#  (Struct(ref=TATAA, alt=T), 560),
#  (Struct(ref=TTATC, alt=T), 558),
#  (Struct(ref=CTTTA, alt=C), 556),
#  (Struct(ref=CAGAG, alt=C), 552),
#  (Struct(ref=CAAAG, alt=C), 551),
#  (Struct(ref=CTAT, alt=C), 549),
#  (Struct(ref=CTTT, alt=C), 547),
#  (Struct(ref=CAGTT, alt=C), 544),
#  (Struct(ref=A, alt=ACTT), 541),
#  (Struct(ref=ATTGT, alt=A), 535),
#  (Struct(ref=T, alt=TAAC), 522),
#  (Struct(ref=GTCT, alt=G), 521),
#  (Struct(ref=CACAA, alt=C), 519),
#  (Struct(ref=C, alt=CATT), 517),
#  (Struct(ref=AAAAAC, alt=A), 514),
#  (Struct(ref=CATTT, alt=C), 513),
#  (Struct(ref=AGAT, alt=A), 512),
#  (Struct(ref=GAAC, alt=G), 511),
#  (Struct(ref=TTGTC, alt=T), 510),
#  (Struct(ref=GAAT, alt=G), 506),
#  (Struct(ref=CAGAT, alt=C), 495),
#  (Struct(ref=TCAA, alt=T), 494),
#  (Struct(ref=GCTT, alt=G), 492),
#  (Struct(ref=TTTTTC, alt=T), 492),
#  (Struct(ref=G, alt=GGC), 485),
#  (Struct(ref=TTAAG, alt=T), 482),
#  (Struct(ref=A, alt=AATT), 478),
#  (Struct(ref=CATG, alt=C), 478),
#  (Struct(ref=TTTTTG, alt=T), 474),
#  (Struct(ref=AAAGG, alt=A), 474),
#  (Struct(ref=T, alt=TATC), 469),
#  (Struct(ref=T, alt=TTAA), 468),
#  (Struct(ref=AAAAAT, alt=A), 466),
#  (Struct(ref=GTGTT, alt=G), 463),
#  (Struct(ref=G, alt=GCC), 460),
#  (Struct(ref=AATTT, alt=A), 459),
#  (Struct(ref=ATAGT, alt=A), 457),
#  (Struct(ref=ATTTC, alt=A), 456),
#  (Struct(ref=CCAAA, alt=C), 454),
#  (Struct(ref=GACA, alt=G), 454),
#  (Struct(ref=GTTTA, alt=G), 451),
#  (Struct(ref=CCCT, alt=C), 450),
#  (Struct(ref=TACAC, alt=T), 449),
#  (Struct(ref=AATAG, alt=A), 446),
#  (Struct(ref=ACACT, alt=A), 442),
#  (Struct(ref=ACAT, alt=A), 438),
#  (Struct(ref=ATTT, alt=A), 437),
#  (Struct(ref=TGTGA, alt=T), 435),
#  (Struct(ref=GTGT, alt=G), 434),
#  (Struct(ref=GGAAA, alt=G), 430),
#  (Struct(ref=T, alt=TAAG), 429),
#  (Struct(ref=GCC, alt=G), 426),
#  (Struct(ref=CCTCT, alt=C), 422),
#  (Struct(ref=AAGAC, alt=A), 419),
#  (Struct(ref=TTGA, alt=T), 417),
#  (Struct(ref=TTAAC, alt=T), 417),
#  (Struct(ref=A, alt=AAAAG), 416),
#  (Struct(ref=AAAGT, alt=A), 414),
#  (Struct(ref=A, alt=AGC), 413),
#  (Struct(ref=CCG, alt=C), 411),
#  (Struct(ref=CTAA, alt=C), 410),
#  (Struct(ref=AATC, alt=A), 408),
#  (Struct(ref=AGAAG, alt=A), 407),
#  (Struct(ref=GTAT, alt=G), 405),
#  (Struct(ref=GTTGT, alt=G), 403),
#  (Struct(ref=T, alt=TAAAC), 392),
#  (Struct(ref=CTTAT, alt=C), 391),
#  (Struct(ref=ATACT, alt=A), 391),
#  (Struct(ref=TCTTA, alt=T), 384),
#  (Struct(ref=GATAA, alt=G), 383),
#  (Struct(ref=TAATC, alt=T), 383),
#  (Struct(ref=TCTA, alt=T), 382),
#  (Struct(ref=TTTCC, alt=T), 381),
#  (Struct(ref=CCCA, alt=C), 381),
#  (Struct(ref=CTAAT, alt=C), 380),
#  (Struct(ref=GGTT, alt=G), 372),
#  (Struct(ref=A, alt=ATTT), 372),
#  (Struct(ref=GACAA, alt=G), 371),
#  (Struct(ref=ACCT, alt=A), 370),
#  (Struct(ref=T, alt=TAAA), 369),
#  (Struct(ref=TCTCA, alt=T), 368),
#  (Struct(ref=GATT, alt=G), 366),
#  (Struct(ref=AAGT, alt=A), 365),
#  (Struct(ref=ATAG, alt=A), 365),
#  (Struct(ref=ATTCT, alt=A), 365),
#  (Struct(ref=TTAAAA, alt=T), 365),
#  (Struct(ref=TTAGA, alt=T), 362),
#  (Struct(ref=C, alt=CAAAT), 360),
#  (Struct(ref=TCTAA, alt=T), 359),
#  (Struct(ref=ATATC, alt=A), 353),
#  (Struct(ref=CTTAA, alt=C), 352),
#  (Struct(ref=GTAA, alt=G), 352),
#  (Struct(ref=TTTTTA, alt=T), 351),
#  (Struct(ref=TATAG, alt=T), 348),
#  (Struct(ref=C, alt=CTGTT), 342),
#  (Struct(ref=TGATA, alt=T), 340),
#  (Struct(ref=CACAG, alt=C), 339),
#  (Struct(ref=TCTTC, alt=T), 338),
#  (Struct(ref=CCAA, alt=C), 337),
#  (Struct(ref=GGGA, alt=G), 336),
#  (Struct(ref=ACTTT, alt=A), 335),
#  (Struct(ref=ACAC, alt=A), 333),
#  (Struct(ref=C, alt=CCG), 332),
#  (Struct(ref=GAATA, alt=G), 332),
#  (Struct(ref=A, alt=AGAT), 332),
#  (Struct(ref=C, alt=CAAT), 329),
#  (Struct(ref=ATGTT, alt=A), 328),
#  (Struct(ref=CTTTT, alt=C), 327),
#  (Struct(ref=CCAT, alt=C), 327),
#  (Struct(ref=TTCA, alt=T), 327),
#  (Struct(ref=A, alt=ATCT), 327),
#  (Struct(ref=CCCTT, alt=C), 326),
#  (Struct(ref=C, alt=CTATT), 325),
#  (Struct(ref=TGTA, alt=T), 324),
#  (Struct(ref=TGGA, alt=T), 322),
#  (Struct(ref=CAGAA, alt=C), 321),
#  (Struct(ref=TGTAA, alt=T), 320),
#  (Struct(ref=AAGAT, alt=A), 318),
#  (Struct(ref=CTTGT, alt=C), 317),
#  (Struct(ref=GAAAC, alt=G), 315),
#  (Struct(ref=GTTTC, alt=G), 314),
#  (Struct(ref=A, alt=ATTG), 314),
#  (Struct(ref=CTCTA, alt=C), 314),
#  (Struct(ref=AGTTT, alt=A), 310),
#  (Struct(ref=CAAA, alt=C), 309),
#  (Struct(ref=ATAAG, alt=A), 309),
#  (Struct(ref=CTTTCT, alt=C), 308),
#  (Struct(ref=A, alt=ATGT), 308),
#  (Struct(ref=CTCA, alt=C), 307),
#  (Struct(ref=A, alt=ATTC), 306),
#  (Struct(ref=TTAG, alt=T), 305),
#  (Struct(ref=GTATT, alt=G), 304),
#  (Struct(ref=C, alt=CAAA), 302),
#  (Struct(ref=GAAAT, alt=G), 302),
#  (Struct(ref=TAACA, alt=T), 302),
#  (Struct(ref=CATCT, alt=C), 301),
#  (Struct(ref=TTATA, alt=T), 300),
#  (Struct(ref=ATCTG, alt=A), 300),
#  (Struct(ref=C, alt=CAGG), 298),
#  (Struct(ref=ATCTT, alt=A), 298),
#  (Struct(ref=CTAAA, alt=C), 297),
#  (Struct(ref=CGA, alt=C), 297),
#  (Struct(ref=G, alt=GTTA), 297),
#  (Struct(ref=GTCTC, alt=G), 295),
#  (Struct(ref=C, alt=CTAT), 295),
#  (Struct(ref=AACT, alt=A), 295),
#  (Struct(ref=ACTGT, alt=A), 294),
#  (Struct(ref=ATAAC, alt=A), 293),
#  (Struct(ref=A, alt=AGTT), 293),
#  (Struct(ref=GAATT, alt=G), 292),
#  (Struct(ref=ATAC, alt=A), 291),
#  (Struct(ref=AACAG, alt=A), 290),
#  (Struct(ref=TCAC, alt=T), 289),
#  (Struct(ref=AATAT, alt=A), 286),
#  (Struct(ref=ACTCT, alt=A), 285),
#  (Struct(ref=CATAA, alt=C), 285),
#  (Struct(ref=AGAGT, alt=A), 285),
#  (Struct(ref=GAGAC, alt=G), 284),
#  (Struct(ref=TAGC, alt=T), 284),
#  (Struct(ref=CCTAA, alt=C), 284),
#  (Struct(ref=ACTAT, alt=A), 282),
#  (Struct(ref=T, alt=TTTTTG), 282),
#  (Struct(ref=TTAC, alt=T), 280),
#  (Struct(ref=C, alt=CTTA), 280),
#  (Struct(ref=CTGAG, alt=C), 279),
#  (Struct(ref=GTCTT, alt=G), 278),
#  (Struct(ref=TTCTG, alt=T), 277),
#  (Struct(ref=C, alt=CTTT), 274),
#  (Struct(ref=CAGT, alt=C), 273),
#  (Struct(ref=T, alt=TGAA), 272),
#  (Struct(ref=TCTG, alt=T), 272),
#  (Struct(ref=CGTT, alt=C), 271),
#  (Struct(ref=TAAAAC, alt=T), 271),
#  (Struct(ref=ATCTC, alt=A), 271),
#  (Struct(ref=C, alt=CTTTA), 270),
#  (Struct(ref=TGTC, alt=T), 269),
#  (Struct(ref=TAGTG, alt=T), 269),
#  (Struct(ref=TTGG, alt=T), 268),
#  (Struct(ref=TTTGA, alt=T), 268),
#  (Struct(ref=ATGTG, alt=A), 268),
#  (Struct(ref=TAAATA, alt=T), 265),
#  (Struct(ref=CCTGT, alt=C), 264),
#  (Struct(ref=TGTTA, alt=T), 263),
#  (Struct(ref=G, alt=GTTT), 263),
#  (Struct(ref=C, alt=CATA), 261),
#  (Struct(ref=CTGA, alt=C), 260),
#  (Struct(ref=A, alt=AATG), 260),
#  (Struct(ref=ATAAAT, alt=A), 258),
#  (Struct(ref=GTTAT, alt=G), 257),
#  (Struct(ref=G, alt=GATA), 257),
#  (Struct(ref=A, alt=AAGG), 257),
#  (Struct(ref=GTCTA, alt=G), 256),
#  (Struct(ref=TTCTA, alt=T), 256),
#  (Struct(ref=GGTTT, alt=G), 255),
#  (Struct(ref=TATATAC, alt=T), 254),
#  (Struct(ref=C, alt=CAGA), 254),
#  (Struct(ref=GCAA, alt=G), 254),
#  (Struct(ref=TAAGA, alt=T), 252),
#  (Struct(ref=C, alt=CTGT), 251),
#  (Struct(ref=ATCC, alt=A), 250),
#  (Struct(ref=CCTAT, alt=C), 250),
#  (Struct(ref=AAACT, alt=A), 250),
#  (Struct(ref=T, alt=TTAAA), 248),
#  (Struct(ref=TTGAG, alt=T), 248),
#  (Struct(ref=AAGC, alt=A), 247),
#  (Struct(ref=T, alt=TTTTTC), 246),
#  (Struct(ref=TCTGA, alt=T), 245),
#  (Struct(ref=CTGAT, alt=C), 245),
#  (Struct(ref=ATTAC, alt=A), 245),
#  (Struct(ref=ATTAG, alt=A), 244),
#  (Struct(ref=C, alt=CTTG), 244),
#  (Struct(ref=TGAGA, alt=T), 243),
#  (Struct(ref=AAAAAAG, alt=A), 243),
#  (Struct(ref=GATTA, alt=G), 242),
#  (Struct(ref=TACAA, alt=T), 242),
#  (Struct(ref=GTTT, alt=G), 241),
#  (Struct(ref=ATGG, alt=A), 240),
#  (Struct(ref=C, alt=CATTT), 240),
#  (Struct(ref=T, alt=TGAG), 240),
#  (Struct(ref=GTTAA, alt=G), 239),
#  (Struct(ref=CCTGA, alt=C), 239),
#  (Struct(ref=TAAAA, alt=T), 238),
#  (Struct(ref=T, alt=TTCTC), 238),
#  (Struct(ref=GAAA, alt=G), 238),
#  (Struct(ref=TGAAA, alt=T), 237),
#  (Struct(ref=GTGA, alt=G), 237),
#  (Struct(ref=TACC, alt=T), 237),
#  (Struct(ref=TCAGA, alt=T), 237),
#  (Struct(ref=CCTG, alt=C), 236),
#  (Struct(ref=ACAGT, alt=A), 236),
#  (Struct(ref=CCTA, alt=C), 236),
#  (Struct(ref=C, alt=CTAA), 236),
#  (Struct(ref=ACAG, alt=A), 235),
#  (Struct(ref=GCAAA, alt=G), 235),
#  (Struct(ref=AAGTT, alt=A), 232),
#  (Struct(ref=T, alt=TCAAA), 232),
#  (Struct(ref=AACTT, alt=A), 231),
#  (Struct(ref=C, alt=CAAG), 231),
#  (Struct(ref=TCG, alt=T), 229),
#  (Struct(ref=GCCT, alt=G), 228),
#  (Struct(ref=T, alt=TAGA), 228),
#  (Struct(ref=TCCTC, alt=T), 226),
#  (Struct(ref=CAAAA, alt=C), 226),
#  (Struct(ref=C, alt=CACAT), 224),
#  (Struct(ref=G, alt=GTAT), 224),
#  (Struct(ref=GGAGA, alt=G), 223),
#  (Struct(ref=CACT, alt=C), 222),
#  (Struct(ref=A, alt=AAAAAC), 222),
#  (Struct(ref=T, alt=TAAAG), 221),
#  (Struct(ref=T, alt=TTTAA), 221),
#  (Struct(ref=A, alt=ATTTG), 221),
#  (Struct(ref=T, alt=TATAC), 219),
#  (Struct(ref=GTATA, alt=G), 219),
#  (Struct(ref=G, alt=GGAA), 217),
#  (Struct(ref=GCTTT, alt=G), 217),
#  (Struct(ref=GTGTC, alt=G), 216),
#  (Struct(ref=A, alt=ACTC), 216),
#  (Struct(ref=GATTT, alt=G), 216),
#  (Struct(ref=ATTTAT, alt=A), 216),
#  (Struct(ref=G, alt=GAAA), 214),
#  (Struct(ref=T, alt=TACA), 214),
#  (Struct(ref=C, alt=CCTTT), 213),
#  (Struct(ref=TTGAC, alt=T), 212),
#  (Struct(ref=T, alt=TTCC), 211),
#  (Struct(ref=GGGT, alt=G), 211),
#  (Struct(ref=CTCTTT, alt=C), 210),
#  (Struct(ref=CATAT, alt=C), 210),
#  (Struct(ref=TAAAAG, alt=T), 209),
#  (Struct(ref=GCTCT, alt=G), 208),
#  (Struct(ref=GTTCT, alt=G), 208),
#  (Struct(ref=GAAGT, alt=G), 207),
#  (Struct(ref=G, alt=GTGTA), 206),
#  (Struct(ref=C, alt=CTTAT), 206),
#  (Struct(ref=T, alt=TTGA), 206),
#  (Struct(ref=G, alt=GTAA), 206),
#  (Struct(ref=TAATAA, alt=T), 206),
#  (Struct(ref=TTGTG, alt=T), 204),
#  (Struct(ref=TTATAA, alt=T), 204),
#  (Struct(ref=ACAAT, alt=A), 204),
#  (Struct(ref=G, alt=GTTTA), 202),
#  (Struct(ref=GAGAT, alt=G), 201),
#  (Struct(ref=CTCCT, alt=C), 201),
#  (Struct(ref=CTAAG, alt=C), 201),
#  (Struct(ref=G, alt=GTTC), 201),
#  (Struct(ref=T, alt=TAGAG), 200),
#  (Struct(ref=TTTAG, alt=T), 200),
#  (Struct(ref=GAACA, alt=G), 199),
#  (Struct(ref=GTAAA, alt=G), 198),
#  (Struct(ref=T, alt=TCAA), 197),
#  (Struct(ref=GCTC, alt=G), 197),
#  (Struct(ref=CAATA, alt=C), 195),
#  (Struct(ref=GAGGA, alt=G), 194),
#  (Struct(ref=A, alt=ATTTC), 193),
#  (Struct(ref=GTCC, alt=G), 193),
#  (Struct(ref=T, alt=TACAC), 193),
#  (Struct(ref=GATC, alt=G), 193),
#  (Struct(ref=GGGAA, alt=G), 192),
#  (Struct(ref=GCTAA, alt=G), 192),
#  (Struct(ref=CATTA, alt=C), 192),
#  (Struct(ref=AAGGG, alt=A), 190),
#  (Struct(ref=CTTAG, alt=C), 190),
#  (Struct(ref=G, alt=GCTT), 190),
#  (Struct(ref=G, alt=GAAT), 190),
#  (Struct(ref=A, alt=AATC), 189),
#  (Struct(ref=A, alt=ATATG), 189),
#  (Struct(ref=CGG, alt=C), 189),
#  (Struct(ref=C, alt=CGA), 189),
#  (Struct(ref=TATATATA, alt=T), 189),
#  (Struct(ref=ACTG, alt=A), 189),
#  (Struct(ref=AGTG, alt=A), 187),
#  (Struct(ref=GTCA, alt=G), 187),
#  (Struct(ref=AACTC, alt=A), 186),
#  (Struct(ref=AAATG, alt=A), 186),
#  (Struct(ref=TTAAAG, alt=T), 186),
#  (Struct(ref=A, alt=AAAGG), 184),
#  (Struct(ref=ATATATG, alt=A), 184),
#  (Struct(ref=CTGTG, alt=C), 183),
#  (Struct(ref=AACC, alt=A), 183),
#  (Struct(ref=C, alt=CATG), 183),
#  (Struct(ref=CCAGA, alt=C), 183),
#  (Struct(ref=C, alt=CTAAA), 183),
#  (Struct(ref=C, alt=CGG), 182),
#  (Struct(ref=TAGTA, alt=T), 182),
#  (Struct(ref=C, alt=CTTTG), 181),
#  (Struct(ref=TACTA, alt=T), 181),
#  (Struct(ref=TTCCC, alt=T), 181),
#  (Struct(ref=G, alt=GATT), 180),
#  (Struct(ref=TTGC, alt=T), 180),
#  (Struct(ref=CTATA, alt=C), 180),
#  (Struct(ref=ATGAG, alt=A), 180),
#  (Struct(ref=CATAG, alt=C), 180),
#  (Struct(ref=GGATA, alt=G), 180),
#  (Struct(ref=AATAC, alt=A), 179),
#  (Struct(ref=CTTTAT, alt=C), 178),
#  (Struct(ref=C, alt=CAATA), 177),
#  (Struct(ref=GCCA, alt=G), 177),
#  (Struct(ref=CAACA, alt=C), 177),
#  (Struct(ref=G, alt=GTATT), 177),
#  (Struct(ref=C, alt=CAGAT), 177),
#  (Struct(ref=ATTATT, alt=A), 176),
#  (Struct(ref=T, alt=TAGAC), 176),
#  (Struct(ref=GGAT, alt=G), 175),
#  (Struct(ref=T, alt=TTTCC), 175),
#  (Struct(ref=G, alt=GAAC), 173),
#  (Struct(ref=CACACAT, alt=C), 173),
#  (Struct(ref=CAAGT, alt=C), 173),
#  (Struct(ref=A, alt=AATTT), 172),
#  (Struct(ref=ATATTT, alt=A), 171),
#  (Struct(ref=C, alt=CCCT), 171),
#  (Struct(ref=AAAAAAC, alt=A), 169),
#  (Struct(ref=A, alt=AAATT), 169),
#  (Struct(ref=T, alt=TAACA), 168),
#  (Struct(ref=G, alt=GTCT), 168),
#  (Struct(ref=C, alt=CCCA), 168),
#  (Struct(ref=CTTTTA, alt=C), 168),
#  (Struct(ref=T, alt=TAGG), 167),
#  (Struct(ref=CAGTG, alt=C), 167),
#  (Struct(ref=GTGTGTA, alt=G), 166),
#  (Struct(ref=AATCT, alt=A), 166),
#  (Struct(ref=T, alt=TAGAA), 166),
#  (Struct(ref=AGGT, alt=A), 165),
#  (Struct(ref=T, alt=TTAC), 165),
#  (Struct(ref=T, alt=TCG), 165),
#  (Struct(ref=G, alt=GGGA), 164),
#  (Struct(ref=TTTTAA, alt=T), 163),
#  (Struct(ref=CTTCTT, alt=C), 163),
#  (Struct(ref=GCTA, alt=G), 163),
#  (Struct(ref=C, alt=CAAAG), 162),
#  (Struct(ref=CCAG, alt=C), 162),
#  (Struct(ref=TCCC, alt=T), 162),
#  (Struct(ref=CCTTTT, alt=C), 162),
#  (Struct(ref=C, alt=CTTTT), 161),
#  (Struct(ref=C, alt=CCAT), 161),
#  (Struct(ref=AGAC, alt=A), 161),
#  (Struct(ref=C, alt=CTGA), 161),
#  (Struct(ref=C, alt=CAAAA), 161),
#  (Struct(ref=ATTTT, alt=A), 161),
#  (Struct(ref=TATTG, alt=T), 160),
#  (Struct(ref=CAACT, alt=C), 160),
#  (Struct(ref=GCTGT, alt=G), 160),
#  (Struct(ref=TTTAC, alt=T), 159),
#  (Struct(ref=A, alt=ATTTT), 158),
#  (Struct(ref=TGTGC, alt=T), 158),
#  (Struct(ref=GAGT, alt=G), 157),
#  (Struct(ref=TCCA, alt=T), 157),
#  (Struct(ref=C, alt=CAGAG), 157),
#  (Struct(ref=C, alt=CAGTT), 157),
#  (Struct(ref=TGAC, alt=T), 156),
#  (Struct(ref=T, alt=TATA), 156),
#  (Struct(ref=AAATC, alt=A), 156),
#  (Struct(ref=TATTC, alt=T), 156),
#  (Struct(ref=TATATATAC, alt=T), 155),
#  (Struct(ref=T, alt=TCTC), 155),
#  (Struct(ref=T, alt=TTAAG), 155),
#  (Struct(ref=G, alt=GTTTT), 154),
#  (Struct(ref=CCATT, alt=C), 154),
#  (Struct(ref=C, alt=CAGT), 154),
#  (Struct(ref=AGAGG, alt=A), 154),
#  (Struct(ref=TTTCTC, alt=T), 154),
#  (Struct(ref=A, alt=ACAT), 154),
#  (Struct(ref=TCAG, alt=T), 153),
#  (Struct(ref=G, alt=GTATA), 153),
#  (Struct(ref=T, alt=TAAAA), 153),
#  (Struct(ref=GACT, alt=G), 152),
#  (Struct(ref=G, alt=GAAAT), 152),
#  (Struct(ref=ATTTCT, alt=A), 151),
#  (Struct(ref=TGGG, alt=T), 149),
#  (Struct(ref=AGCT, alt=A), 149),
#  (Struct(ref=TCTCC, alt=T), 149),
#  (Struct(ref=A, alt=ATCTT), 149),
#  (Struct(ref=AAATAT, alt=A), 149),
#  (Struct(ref=A, alt=ATGTT), 148),
#  (Struct(ref=A, alt=ATTGT), 148),
#  (Struct(ref=C, alt=CCCTT), 148),
#  (Struct(ref=ATAACT, alt=A), 147),
#  (Struct(ref=TTATG, alt=T), 147),
#  (Struct(ref=T, alt=TTCA), 147),
#  (Struct(ref=A, alt=ATGTG), 146),
#  (Struct(ref=CAAAAT, alt=C), 146),
#  (Struct(ref=GTAGA, alt=G), 146),
#  (Struct(ref=AATTG, alt=A), 146),
#  (Struct(ref=GCTAT, alt=G), 145),
#  (Struct(ref=C, alt=CATAT), 144),
#  (Struct(ref=G, alt=GGAAA), 144),
#  (Struct(ref=ATAAAG, alt=A), 143),
#  (Struct(ref=AAAGAG, alt=A), 143),
#  (Struct(ref=AGGAG, alt=A), 143),
#  (Struct(ref=TAATG, alt=T), 141),
#  (Struct(ref=TTTAAA, alt=T), 140),
#  (Struct(ref=CCTCA, alt=C), 140),
#  (Struct(ref=A, alt=AAGAG), 140),
#  (Struct(ref=TATATC, alt=T), 140),
#  (Struct(ref=A, alt=ACTTT), 140),
#  (Struct(ref=GGGC, alt=G), 140),
#  (Struct(ref=T, alt=TTAG), 139),
#  (Struct(ref=A, alt=ATAT), 139),
#  (Struct(ref=T, alt=TATG), 139),
#  (Struct(ref=GAAAA, alt=G), 139),
#  (Struct(ref=GCTGA, alt=G), 138),
#  (Struct(ref=GAACT, alt=G), 138),
#  (Struct(ref=A, alt=AATAT), 137),
#  (Struct(ref=A, alt=ATATC), 136),
#  (Struct(ref=AAAATT, alt=A), 136),
#  (Struct(ref=C, alt=CAATT), 136),
#  (Struct(ref=TATAAC, alt=T), 135),
#  (Struct(ref=A, alt=ACCT), 135),
#  (Struct(ref=GTATC, alt=G), 135),
#  (Struct(ref=GAAAGA, alt=G), 135),
#  (Struct(ref=T, alt=TTATA), 135),
#  (Struct(ref=G, alt=GATAA), 135),
#  (Struct(ref=GTTTT, alt=G), 134),
#  (Struct(ref=AACTG, alt=A), 134),
#  (Struct(ref=G, alt=GCCT), 134),
#  (Struct(ref=TGCA, alt=T), 133),
#  (Struct(ref=C, alt=CTCTG), 133),
#  (Struct(ref=CCCG, alt=C), 133),
#  (Struct(ref=TTTTTTG, alt=T), 133),
#  (Struct(ref=ACTTTT, alt=A), 133),
#  (Struct(ref=T, alt=TGGA), 132),
#  (Struct(ref=C, alt=CTAAT), 131),
#  (Struct(ref=C, alt=CCAA), 131),
#  (Struct(ref=A, alt=ATAG), 130),
#  (Struct(ref=AACAC, alt=A), 130),
#  (Struct(ref=AAAAAAT, alt=A), 130),
#  (Struct(ref=T, alt=TTTTTA), 130),
#  (Struct(ref=A, alt=ATCTG), 129),
#  (Struct(ref=CTGG, alt=C), 129),
#  (Struct(ref=CATTTT, alt=C), 129),
#  (Struct(ref=ATTAAT, alt=A), 129),
#  (Struct(ref=GGCT, alt=G), 129),
#  (Struct(ref=AATTTT, alt=A), 128),
#  (Struct(ref=T, alt=TAGC), 128),
#  (Struct(ref=CCTTA, alt=C), 128),
#  (Struct(ref=G, alt=GACA), 128),
#  (Struct(ref=CTTATT, alt=C), 127),
#  (Struct(ref=AATAAT, alt=A), 127),
#  (Struct(ref=G, alt=GGGT), 127),
#  (Struct(ref=C, alt=CACTT), 127),
#  (Struct(ref=C, alt=CTCTA), 127),
#  (Struct(ref=G, alt=GCAA), 126),
#  (Struct(ref=G, alt=GTGA), 126),
#  (Struct(ref=A, alt=AACTT), 125),
#  (Struct(ref=AAAAAAAG, alt=A), 125),
#  (Struct(ref=TAACTC, alt=T), 125),
#  (Struct(ref=C, alt=CTTAA), 125),
#  (Struct(ref=ATAATT, alt=A), 124),
#  (Struct(ref=T, alt=TGTA), 124),
#  (Struct(ref=ATGC, alt=A), 124),
#  (Struct(ref=T, alt=TCTA), 124),
#  (Struct(ref=TATAAA, alt=T), 123),
#  (Struct(ref=CATATT, alt=C), 123),
#  (Struct(ref=T, alt=TTATC), 123),
#  (Struct(ref=T, alt=TTGG), 123),
#  (Struct(ref=A, alt=ATAC), 123),
#  (Struct(ref=A, alt=ATTCT), 123),
#  (Struct(ref=G, alt=GAATA), 122),
#  (Struct(ref=T, alt=TGGG), 122),
#  (Struct(ref=TACAG, alt=T), 121),
#  (Struct(ref=G, alt=GAAAC), 121),
#  (Struct(ref=TACTG, alt=T), 121),
#  (Struct(ref=GTAAT, alt=G), 121),
#  (Struct(ref=AATGT, alt=A), 120),
#  (Struct(ref=AATTAT, alt=A), 120),
#  (Struct(ref=G, alt=GTAAA), 120),
#  (Struct(ref=TTTTTTC, alt=T), 120),
#  (Struct(ref=A, alt=ATGG), 119),
#  (Struct(ref=CCAAT, alt=C), 119),
#  (Struct(ref=GAGTT, alt=G), 119),
#  (Struct(ref=ACACG, alt=A), 119),
#  (Struct(ref=ATACTT, alt=A), 119),
#  (Struct(ref=GGTA, alt=G), 119),
#  (Struct(ref=G, alt=GAGAT), 118),
#  (Struct(ref=T, alt=TCAC), 118),
#  (Struct(ref=G, alt=GTCA), 118),
#  (Struct(ref=TTGAA, alt=T), 118),
#  (Struct(ref=G, alt=GCTA), 117),
#  (Struct(ref=GCAT, alt=G), 117),
#  (Struct(ref=T, alt=TGCA), 117),
#  (Struct(ref=ATTTTC, alt=A), 117),
#  (Struct(ref=A, alt=AGTG), 117),
#  (Struct(ref=C, alt=CCAAA), 117),
#  (Struct(ref=TCTTTA, alt=T), 117),
#  (Struct(ref=GAAGAA, alt=G), 116),
#  (Struct(ref=TTTAAG, alt=T), 115),
#  (Struct(ref=CTGAA, alt=C), 115),
#  (Struct(ref=TATTTA, alt=T), 115),
#  (Struct(ref=GGCA, alt=G), 115),
#  (Struct(ref=C, alt=CTATA), 115),
#  (Struct(ref=CAAATT, alt=C), 115),
#  (Struct(ref=A, alt=AAGAT), 115),
#  (Struct(ref=GACC, alt=G), 114),
#  (Struct(ref=T, alt=TATCA), 114),
#  (Struct(ref=A, alt=AAAAAT), 114),
#  (Struct(ref=CACTA, alt=C), 114),
#  (Struct(ref=G, alt=GTCTT), 113),
#  (Struct(ref=T, alt=TAAAAC), 113),
#  (Struct(ref=TCACA, alt=T), 113),
#  (Struct(ref=TTGTA, alt=T), 113),
#  (Struct(ref=T, alt=TCCC), 113),
#  (Struct(ref=CTCAT, alt=C), 112),
#  (Struct(ref=CTTTAA, alt=C), 112),
#  (Struct(ref=GACTT, alt=G), 112),
#  (Struct(ref=CATGT, alt=C), 112),
#  (Struct(ref=CAGTA, alt=C), 111),
#  (Struct(ref=GCAC, alt=G), 111),
#  (Struct(ref=C, alt=CTGAT), 111),
#  (Struct(ref=CTTCA, alt=C), 111),
#  (Struct(ref=GACTA, alt=G), 111),
#  (Struct(ref=TAAATC, alt=T), 110),
#  (Struct(ref=A, alt=AGAG), 110),
#  (Struct(ref=T, alt=TATAG), 110),
#  (Struct(ref=C, alt=CATAA), 110),
#  (Struct(ref=TATCA, alt=T), 110),
#  (Struct(ref=T, alt=TGTAA), 110),
#  (Struct(ref=TTATTA, alt=T), 109),
#  (Struct(ref=ATGTC, alt=A), 109),
#  (Struct(ref=ATGAT, alt=A), 109),
#  (Struct(ref=T, alt=TACTC), 109),
#  (Struct(ref=A, alt=ATAAG), 109),
#  (Struct(ref=TGGC, alt=T), 108),
#  (Struct(ref=A, alt=AACT), 108),
#  (Struct(ref=ATATATT, alt=A), 108),
#  (Struct(ref=A, alt=AGTTT), 108),
#  (Struct(ref=G, alt=GTTAT), 108),
#  (Struct(ref=GTTAC, alt=G), 107),
#  (Struct(ref=GAGC, alt=G), 107),
#  (Struct(ref=TTTCA, alt=T), 107),
#  (Struct(ref=AAGTC, alt=A), 107),
#  (Struct(ref=TGAAAA, alt=T), 107),
#  (Struct(ref=AGTGT, alt=A), 107),
#  (Struct(ref=A, alt=AGGG), 106),
#  (Struct(ref=A, alt=ATCC), 106),
#  (Struct(ref=G, alt=GGTT), 106),
#  (Struct(ref=TTACTC, alt=T), 106),
#  (Struct(ref=A, alt=ATAGT), 106),
#  (Struct(ref=CTCAA, alt=C), 105),
#  (Struct(ref=A, alt=ACTG), 105),
#  (Struct(ref=CTCAG, alt=C), 105),
#  (Struct(ref=GGTGA, alt=G), 105),
#  (Struct(ref=A, alt=ACAG), 104),
#  (Struct(ref=G, alt=GTTTC), 104),
#  (Struct(ref=A, alt=AAAAAG), 104),
#  (Struct(ref=A, alt=AAGT), 104),
#  (Struct(ref=A, alt=AAGC), 104),
#  (Struct(ref=GCAGA, alt=G), 104),
#  (Struct(ref=G, alt=GTCTC), 104),
#  (Struct(ref=CACTG, alt=C), 103),
#  (Struct(ref=GTTTAT, alt=G), 103),
#  (Struct(ref=CTTGA, alt=C), 103),
#  (Struct(ref=ATATATATG, alt=A), 102),
#  (Struct(ref=T, alt=TTGTC), 102),
#  (Struct(ref=GGTAA, alt=G), 102),
#  (Struct(ref=C, alt=CTCT), 102),
#  (Struct(ref=AGGG, alt=A), 102),
#  (Struct(ref=CAAGA, alt=C), 102),
#  (Struct(ref=GTAAC, alt=G), 101),
#  (Struct(ref=ATATATAT, alt=A), 101),
#  (Struct(ref=A, alt=ATACT), 100),
#  (Struct(ref=T, alt=TCCA), 100),
#  (Struct(ref=GTAGT, alt=G), 100),
#  (Struct(ref=C, alt=CTTGT), 100),
#  (Struct(ref=G, alt=GGAT), 100),
#  (Struct(ref=CTAGA, alt=C), 100),
#  (Struct(ref=T, alt=TCAG), 100),
#  (Struct(ref=AGATT, alt=A), 99),
#  (Struct(ref=C, alt=CTGG), 99),
#  (Struct(ref=T, alt=TTGC), 99),
#  (Struct(ref=T, alt=TAGTC), 99),
#  (Struct(ref=A, alt=ACCC), 99),
#  (Struct(ref=C, alt=CTCA), 99),
#  (Struct(ref=TGACA, alt=T), 98),
#  (Struct(ref=G, alt=GATTT), 98),
#  (Struct(ref=GTTTGT, alt=G), 98),
#  (Struct(ref=CTTAAT, alt=C), 97),
#  (Struct(ref=A, alt=ATCTC), 97),
#  (Struct(ref=TTACA, alt=T), 97),
#  (Struct(ref=T, alt=TTAAAA), 97),
#  (Struct(ref=TTAATA, alt=T), 97),
#  (Struct(ref=GATAAA, alt=G), 97),
#  (Struct(ref=C, alt=CCTAT), 97),
#  (Struct(ref=ATGAC, alt=A), 96),
#  (Struct(ref=G, alt=GCTC), 96),
#  (Struct(ref=C, alt=CTGAG), 96),
#  (Struct(ref=G, alt=GGCT), 96),
#  (Struct(ref=TAAAGA, alt=T), 96),
#  (Struct(ref=T, alt=TGTC), 96),
#  (Struct(ref=AGTC, alt=A), 95),
#  (Struct(ref=TGTCA, alt=T), 95),
#  (Struct(ref=T, alt=TCTAA), 95),
#  (Struct(ref=CGAG, alt=C), 95),
#  (Struct(ref=GATAT, alt=G), 95),
#  (Struct(ref=C, alt=CACAG), 95),
#  (Struct(ref=CTATTT, alt=C), 94),
#  (Struct(ref=AGAAAG, alt=A), 94),
#  (Struct(ref=T, alt=TTAGA), 93),
#  (Struct(ref=GTAC, alt=G), 93),
#  (Struct(ref=T, alt=TGTGA), 93),
#  (Struct(ref=TATATAA, alt=T), 93),
#  (Struct(ref=TTAAAC, alt=T), 93),
#  (Struct(ref=TATAAG, alt=T), 93),
#  (Struct(ref=TCTTTC, alt=T), 93),
#  (Struct(ref=A, alt=AACC), 92),
#  (Struct(ref=GTGAA, alt=G), 92),
#  (Struct(ref=CAAACA, alt=C), 92),
#  (Struct(ref=T, alt=TTCTA), 92),
#  (Struct(ref=C, alt=CAGAA), 91),
#  (Struct(ref=GCTTA, alt=G), 91),
#  (Struct(ref=ACATT, alt=A), 91),
#  (Struct(ref=A, alt=ACTCT), 91),
#  (Struct(ref=T, alt=TACC), 91),
#  (Struct(ref=G, alt=GGTTT), 90),
#  (Struct(ref=C, alt=CCTG), 90),
#  (Struct(ref=A, alt=AATAG), 90),
#  (Struct(ref=A, alt=AAGGG), 90),
#  (Struct(ref=T, alt=TAATC), 90),
#  (Struct(ref=TTCAC, alt=T), 90),
#  (Struct(ref=G, alt=GAATT), 90),
#  (Struct(ref=G, alt=GGGC), 90),
#  (Struct(ref=TAAGAA, alt=T), 89),
#  (Struct(ref=G, alt=GCAT), 89),
#  (Struct(ref=GCACA, alt=G), 89),
#  (Struct(ref=C, alt=CCTGT), 89),
#  (Struct(ref=TAAGG, alt=T), 89),
#  (Struct(ref=CCCCA, alt=C), 89),
#  (Struct(ref=T, alt=TGGC), 89),
#  (Struct(ref=T, alt=TATTC), 89),
#  (Struct(ref=ATTACT, alt=A), 88),
#  (Struct(ref=CCAGT, alt=C), 88),
#  (Struct(ref=G, alt=GCAAA), 88),
#  (Struct(ref=T, alt=TGAAA), 88),
#  (Struct(ref=C, alt=CACT), 88),
#  (Struct(ref=A, alt=ATGC), 88),
#  (Struct(ref=AAAAAAAC, alt=A), 87),
#  (Struct(ref=C, alt=CTAAG), 87),
#  (Struct(ref=G, alt=GTCTA), 87),
#  (Struct(ref=G, alt=GACAA), 87),
#  (Struct(ref=TTTTTTA, alt=T), 87),
#  (Struct(ref=C, alt=CCATT), 87),
#  (Struct(ref=T, alt=TCTG), 87),
#  (Struct(ref=A, alt=AAATG), 86),
#  (Struct(ref=C, alt=CTGAA), 86),
#  (Struct(ref=G, alt=GTGTC), 86),
#  (Struct(ref=TGCC, alt=T), 86),
#  (Struct(ref=CCACT, alt=C), 86),
#  (Struct(ref=A, alt=ACTGT), 86),
#  (Struct(ref=ATAGG, alt=A), 86),
#  (Struct(ref=G, alt=GATC), 86),
#  (Struct(ref=A, alt=AGCT), 86),
#  (Struct(ref=CTCTCT, alt=C), 86),
#  (Struct(ref=T, alt=TGTGC), 85),
#  (Struct(ref=CTAGT, alt=C), 85),
#  (Struct(ref=TCAAAA, alt=T), 85),
#  (Struct(ref=ATTAAG, alt=A), 85),
#  (Struct(ref=A, alt=AAGAC), 85),
#  (Struct(ref=TCATC, alt=T), 85),
#  (Struct(ref=AAAGTT, alt=A), 85),
#  (Struct(ref=TTCAA, alt=T), 85),
#  (Struct(ref=G, alt=GCCA), 85),
#  (Struct(ref=TATATATATAC, alt=T), 84),
#  (Struct(ref=C, alt=CTCTT), 84),
#  (Struct(ref=CGTG, alt=C), 84),
#  (Struct(ref=CATATA, alt=C), 84),
#  (Struct(ref=TAAGAG, alt=T), 84),
#  (Struct(ref=TTTATA, alt=T), 84),
#  (Struct(ref=TATATATATA, alt=T), 84),
#  (Struct(ref=TAAGTA, alt=T), 84),
#  (Struct(ref=CATAAA, alt=C), 84),
#  (Struct(ref=GTGC, alt=G), 84),
#  (Struct(ref=T, alt=TGAC), 83),
#  (Struct(ref=C, alt=CCCG), 83),
#  (Struct(ref=G, alt=GTTAA), 83),
#  (Struct(ref=TATTAA, alt=T), 83),
#  (Struct(ref=G, alt=GTAC), 82),
#  (Struct(ref=AGAAT, alt=A), 82),
#  (Struct(ref=T, alt=TAAGA), 81),
#  (Struct(ref=C, alt=CCTAA), 81),
#  (Struct(ref=GTTTTC, alt=G), 81),
#  (Struct(ref=CTGTA, alt=C), 81),
#  (Struct(ref=CTTAAA, alt=C), 81),
#  (Struct(ref=ATATGT, alt=A), 81),
#  (Struct(ref=AGATG, alt=A), 81),
#  (Struct(ref=CATAAT, alt=C), 81),
#  (Struct(ref=A, alt=AGGT), 81),
#  (Struct(ref=AGGC, alt=A), 80),
#  (Struct(ref=A, alt=ATAAC), 80),
#  (Struct(ref=TAATTA, alt=T), 80),
#  (Struct(ref=CAAAAG, alt=C), 80),
#  (Struct(ref=ATATCT, alt=A), 80),
#  (Struct(ref=GACAC, alt=G), 80),
#  (Struct(ref=C, alt=CCAG), 80),
#  (Struct(ref=AATATT, alt=A), 79),
#  (Struct(ref=CGAT, alt=C), 79),
#  (Struct(ref=GAGTA, alt=G), 79),
#  (Struct(ref=G, alt=GATTA), 79),
#  (Struct(ref=CTAG, alt=C), 79),
#  (Struct(ref=CTACT, alt=C), 79),
#  (Struct(ref=CTTTGT, alt=C), 79),
#  (Struct(ref=C, alt=CTGTG), 79),
#  (Struct(ref=GCCC, alt=G), 79),
#  (Struct(ref=T, alt=TCTCA), 79),
#  (Struct(ref=CTGTTT, alt=C), 78),
#  (Struct(ref=TTAAGA, alt=T), 78),
#  (Struct(ref=AAGAAAG, alt=A), 78),
#  (Struct(ref=T, alt=TTGAA), 78),
#  (Struct(ref=C, alt=CTTTAT), 78),
#  (Struct(ref=GTGTGTGTA, alt=G), 78),
#  (Struct(ref=ACCC, alt=A), 78),
#  (Struct(ref=CAACTT, alt=C), 78),
#  (Struct(ref=CGTGT, alt=C), 78),
#  (Struct(ref=CTAATT, alt=C), 78),
#  (Struct(ref=C, alt=CCTCT), 77),
#  (Struct(ref=CCCCT, alt=C), 77),
#  (Struct(ref=T, alt=TTTGA), 77),
#  (Struct(ref=A, alt=AGGC), 77),
#  (Struct(ref=TGAAG, alt=T), 77),
#  (Struct(ref=CTATG, alt=C), 77),
#  (Struct(ref=AAAAAAAAG, alt=A), 77),
#  (Struct(ref=G, alt=GAGAC), 77),
#  (Struct(ref=T, alt=TTAAC), 77),
#  (Struct(ref=T, alt=TCTTA), 76),
#  (Struct(ref=G, alt=GTCC), 76),
#  (Struct(ref=AATAAG, alt=A), 76),
#  (Struct(ref=G, alt=GGGAA), 75),
#  (Struct(ref=AAAGC, alt=A), 75),
#  (Struct(ref=GTTTTA, alt=G), 75),
#  (Struct(ref=GAAATA, alt=G), 75),
#  (Struct(ref=C, alt=CATCT), 75),
#  (Struct(ref=GGTTA, alt=G), 75),
#  (Struct(ref=AGACT, alt=A), 75),
#  (Struct(ref=C, alt=CCTA), 75),
#  ...]

# %% [markdown]
# ### Take a subset of the matrix

# %% [raw]
# indices = list(range(mt.count_cols()))
# import random
# random.shuffle(indices)
# mt_subset = mt.head(18000)
# mt_subset.count()

# %% [markdown]
# ### Quality control

# %% [markdown]
# QC is entirely based on the ability to understand the properties of a dataset. In Hail, the `sample_qc` method produces a set of useful metrics and stores them in a column field.

# %%
mt = hl.sample_qc(mt)

# %%
p = hl.plot.histogram(mt.sample_qc.call_rate, range=(.88,1), legend='Call Rate')
show(p)
# Out:
#   <div class="bk-root" id="0f5c6d6e-0045-4c2a-806d-737c17b2157d"></div>

# %% [markdown]
# ### GWAS

# %% [markdown]
# ####  Logistic Regression

# %%
# Filter for only 2 sub populations then do logistic regression
mt_filt1 = mt.filter_cols(((mt.col.Super_Population_Classification == 0) | (mt.col.Super_Population_Classification == 1)))

print("After filtering for only 2 SupPopulations, %d/1092 samples remaining" % mt_filt1.count_cols())
print ("The SuperPopulations are: ", le.inverse_transform([0, 1]))
# Out:
# After filtering for only 2 SupPopulations, 427/1092 samples remaining
# The SuperPopulations are:  ['AFR' 'AMR']
# /opt/conda/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning:
#
# The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.

# %% [markdown]
# The example above considers a model of the form
# 	``` Prob(population) = sigmoid(β0+β1gt+ε),ε∼N(0,σ2) ```
# where sigmoid is the sigmoid function, the genotype gt is coded as 0 for HomRef, 1 for Het, and 2 for HomVar, and the covariate is.female is coded as for 1 for True (female) and 0 for False (male). The null model sets β1=0.

# %%
#Logistic Regression
gwas_logistic = hl.logistic_regression(
           test='wald',
           y=mt_filt1.col.Super_Population_Classification,
           x=mt_filt1.GT.n_alt_alleles()
       )
gwas_logistic.row.describe()
gwas_logistic.describe()
# Out:
# 2018-08-07 13:01:18 Hail: INFO: logistic_regression: running wald on 427 samples for response variable y,
#     with input variable x, intercept, and 0 additional covariates...
# --------------------------------------------------------
# Type:
#     struct {
#         locus: locus<GRCh37>,
#         alleles: array<str>,
#         rsid: str,
#         qual: float64,
#         filters: set<str>,
#         info: struct {
#             LDAF: float64,
#             AVGPOST: float64,
#             RSQ: float64,
#             ERATE: float64,
#             THETA: float64,
#             CIEND: array<int32>,
#             CIPOS: array<int32>,
#             END: int32,
#             HOMLEN: array<int32>,
#             HOMSEQ: array<str>,
#             SVLEN: int32,
#             SVTYPE: str,
#             AC: array<int32>,
#             AN: int32,
#             AA: str,
#             AF: array<float64>,
#             AMR_AF: float64,
#             ASN_AF: float64,
#             AFR_AF: float64,
#             EUR_AF: float64,
#             VT: str,
#             SNPSOURCE: array<str>
#         },
#         variant_qc: struct {
#             AC: array<int32>,
#             AF: array<float64>,
#             AN: int32,
#             homozygote_count: array<int32>,
#             n_called: int64,
#             n_not_called: int64,
#             call_rate: float32,
#             n_het: int64,
#             n_non_ref: int64,
#             het_freq_hwe: float64,
#             p_value_hwe: float64
#         },
#         logreg: struct {
#             beta: float64,
#             standard_error: float64,
#             z_stat: float64,
#             p_value: float64,
#             fit: struct {
#                 n_iterations: int32,
#                 converged: bool,
#                 exploded: bool
#             }
#         }
#     }
# --------------------------------------------------------
# Source:
#     <hail.matrixtable.MatrixTable object at 0x7fd957610c18>
# Index:
#     ['row']
# --------------------------------------------------------
# ----------------------------------------
# Global fields:
#     None
# ----------------------------------------
# Column fields:
#     's': str
#     'Family_ID': str
#     'Population': str
#     'Population_Description': str
#     'Gender': str
#     'Relationship': str
#     'Unexpected_Parent_Child': str
#     'Non_Paternity': str
#     'Siblings': str
#     'Grandparents': str
#     'Avuncular': str
#     'Half_Siblings': str
#     'Unknown_Second_Order': str
#     'Third_Order': str
#     'In_Low_Coverage_Pilot': str
#     'LC_Pilot_Platforms': str
#     'LC_Pilot_Centers': str
#     'In_High_Coverage_Pilot': str
#     'HC_Pilot_Platforms': str
#     'HC_Pilot_Centers': str
#     'In_Exon_Targetted_Pilot': str
#     'ET_Pilot_Platforms': str
#     'ET_Pilot_Centers': str
#     'Has_Sequence_in_Phase1': str
#     'Phase1_LC_Platform': str
#     'Phase1_LC_Centers': str
#     'Phase1_E_Platform': str
#     'Phase1_E_Centers': str
#     'In_Phase1_Integrated_Variant_Set': str
#     'Has_Phase1_chrY_SNPS': str
#     'Has_phase1_chrY_Deletions': str
#     'Has_phase1_chrMT_SNPs': str
#     'Main_project_LC_Centers': str
#     'Main_project_LC_platform': str
#     'Total_LC_Sequence': str
#     'LC_Non_Duplicated_Aligned_Coverage': str
#     'Main_Project_E_Centers': str
#     'Main_Project_E_Platform': str
#     'Total_Exome_Sequence': str
#     'X_Targets_Covered_to_20x_or_greater': str
#     'VerifyBam_E_Omni_Free': str
#     'VerifyBam_E_Affy_Free': str
#     'VerifyBam_E_Omni_Chip': str
#     'VerifyBam_E_Affy_Chip': str
#     'VerifyBam_LC_Omni_Free': str
#     'VerifyBam_LC_Affy_Free': str
#     'VerifyBam_LC_Omni_Chip': str
#     'VerifyBam_LC_Affy_Chip': str
#     'LC_Indel_Ratio': str
#     'E_Indel_Ratio': str
#     'LC_Passed_QC': str
#     'E_Passed_QC': str
#     'In_Final_Phase_Variant_Calling': str
#     'Has_Omni_Genotypes': str
#     'Has_Axiom_Genotypes': str
#     'Has_Affy_6_0_Genotypes': str
#     'Has_Exome_LOF_Genotypes': str
#     'EBV_Coverage': str
#     'DNA_Source_from_Coriell': str
#     'Has_Sequence_from_Blood_in_Index': str
#     'Super_Population': str
#     'Super_Population_Description': str
#     'Super_Population_Classification': float64
#     'sample_qc': struct {
#         call_rate: float64,
#         n_called: int64,
#         n_not_called: int64,
#         n_hom_ref: int64,
#         n_het: int64,
#         n_hom_var: int64,
#         n_non_ref: int64,
#         n_singleton: int64,
#         n_snp: int64,
#         n_insertion: int64,
#         n_deletion: int64,
#         n_transition: int64,
#         n_transversion: int64,
#         n_star: int64,
#         r_ti_tv: float64,
#         r_het_hom_var: float64,
#         r_insertion_deletion: float64
#     }
# ----------------------------------------
# Row fields:
#     'locus': locus<GRCh37>
#     'alleles': array<str>
#     'rsid': str
#     'qual': float64
#     'filters': set<str>
#     'info': struct {
#         LDAF: float64,
#         AVGPOST: float64,
#         RSQ: float64,
#         ERATE: float64,
#         THETA: float64,
#         CIEND: array<int32>,
#         CIPOS: array<int32>,
#         END: int32,
#         HOMLEN: array<int32>,
#         HOMSEQ: array<str>,
#         SVLEN: int32,
#         SVTYPE: str,
#         AC: array<int32>,
#         AN: int32,
#         AA: str,
#         AF: array<float64>,
#         AMR_AF: float64,
#         ASN_AF: float64,
#         AFR_AF: float64,
#         EUR_AF: float64,
#         VT: str,
#         SNPSOURCE: array<str>
#     }
#     'variant_qc': struct {
#         AC: array<int32>,
#         AF: array<float64>,
#         AN: int32,
#         homozygote_count: array<int32>,
#         n_called: int64,
#         n_not_called: int64,
#         call_rate: float32,
#         n_het: int64,
#         n_non_ref: int64,
#         het_freq_hwe: float64,
#         p_value_hwe: float64
#     }
#     'logreg': struct {
#         beta: float64,
#         standard_error: float64,
#         z_stat: float64,
#         p_value: float64,
#         fit: struct {
#             n_iterations: int32,
#             converged: bool,
#             exploded: bool
#         }
#     }
# ----------------------------------------
# Entry fields:
#     'GT': call
#     'DS': float64
#     'GL': array<float64>
#     'PL': array<int32>
# ----------------------------------------
# Column key: ['s']
# Row key: ['locus', 'alleles']
# Partition key: ['locus']
# ----------------------------------------

# %%
def qqplot(pvals):
    spvals = sorted(filter(lambda x: x and not (isnan(x)), pvals))
    exp = [-log(float(i) / len(spvals), 10) for i in np.arange(1, len(spvals) + 1, 1)]
    obs = [-log(p, 10) for p in spvals]
    p = figure(title="Q Q Plot",
              x_axis_label = 'Expected P-Value (-log10 scale)',
              y_axis_label = 'Observe P-Value (-log10 scale)')
    p.scatter(x=exp, y=obs, color = 'black')
    bound = max(max(exp), max(obs)) * 1.1
    p.line([0, bound], [0, bound], color = 'red')
    show(p)

# %% [raw]
# pvals = gwas_logistic.logreg.p_value.collect()
# qqplot(pvals)

# %% [markdown]
# ####  Linear Regression

# %%
#Linear Regression
gwas_linear = hl.linear_regression(
           test='wald',
           y=mt_filt1.Super_Population_Classification,
           x=mt_filt1.GT.n_alt_alleles(),
       )
gwas_linear.row.describe()
# Out:
# 2018-08-07 13:31:15 Hail: INFO: linear_regression: running on 427 samples for 1 response variable y,
#     with input variable x, intercept, and 0 additional covariates...
# --------------------------------------------------------
# Type:
#     struct {
#         locus: locus<GRCh37>,
#         alleles: array<str>,
#         rsid: str,
#         qual: float64,
#         filters: set<str>,
#         info: struct {
#             LDAF: float64,
#             AVGPOST: float64,
#             RSQ: float64,
#             ERATE: float64,
#             THETA: float64,
#             CIEND: array<int32>,
#             CIPOS: array<int32>,
#             END: int32,
#             HOMLEN: array<int32>,
#             HOMSEQ: array<str>,
#             SVLEN: int32,
#             SVTYPE: str,
#             AC: array<int32>,
#             AN: int32,
#             AA: str,
#             AF: array<float64>,
#             AMR_AF: float64,
#             ASN_AF: float64,
#             AFR_AF: float64,
#             EUR_AF: float64,
#             VT: str,
#             SNPSOURCE: array<str>
#         },
#         variant_qc: struct {
#             AC: array<int32>,
#             AF: array<float64>,
#             AN: int32,
#             homozygote_count: array<int32>,
#             n_called: int64,
#             n_not_called: int64,
#             call_rate: float32,
#             n_het: int64,
#             n_non_ref: int64,
#             het_freq_hwe: float64,
#             p_value_hwe: float64
#         },
#         linreg: struct {
#             n: int32,
#             sum_x: float64,
#             y_transpose_x: float64,
#             beta: float64,
#             standard_error: float64,
#             t_stat: float64,
#             p_value: float64
#         }
#     }
# --------------------------------------------------------
# Source:
#     <hail.matrixtable.MatrixTable object at 0x7fd95c14c160>
# Index:
#     ['row']
# --------------------------------------------------------

# %% [raw]
# p = hl.plot.qq(gwas_linear.linreg.p_value)
# show(p)

# %% [markdown]
# ### PCA

# %% [markdown]
# The linear_regression method can also take column fields to use as covariates. We already annotated our samples with reported ancestry, but it is good to be skeptical of these labels due to human error. Genomes don’t have that problem! Instead of using reported ancestry, we will use genetic ancestry by including computed principal components in our model.
#
# The pca method produces eigenvalues as a list and sample PCs as a Table, and can also produce variant loadings when asked. The hwe_normalized_pca method does the same, using HWE-normalized genotypes for the PCA.

# %%
pca_eigenvalues, pca_scores, _ = hl.hwe_normalized_pca(mt_filt1.GT, k=5)

# %%
p = hl.plot.scatter(pca_scores.scores[0], pca_scores.scores[1],
                    label=common_mt.cols()[pca_scores.s].SuperPopulation,
                    title='PCA', xlabel='PC1', ylabel='PC2')
show(p)

# %% [markdown]
# Now we can rerun our linear regression, controlling by the first few principal components.

# %%
#New table for pca data 
pcatable = pca_score.select(Super_Population = mt_filt1.cols()[pca_score.s].population,
                             PC1 = pca_score.scores[0],
                             PC2 = pca_score.scores[1]
                           )



pca_df = hl.Table.to_pandas(pcatable)
mt_filt1 = mt_filt1.annotate_cols(pca = pca_score[mt_filt1.s])

# %%
gwas_logistic2 = hl.logistic_regression(
           test='lrt',
           y=mt_filt1.col.Super_Population_Classification,
           x=mt_filt1.GT.n_alt_alleles(),
           covariates=[mt_filt1.pca.scores[0], mt_filt1.pca.scores[1], mt_filt1.pca.scores[2],mt_filt1.col.Super_Population_Classification])
       
pvals = gwas_logistic2.logreg.p_value.collect()
qqplot(pvals)

# %%
gwas_linear2 = hl.linear_regression(
           test='wald',
           y=mt_filt1.Super_Population_Classification,
           x=mt_filt1.GT.n_alt_alleles(),
           covariates=[mt_filt1.pca.scores[0], mt_filt1.pca.scores[1], mt_filt1.pca.scores[2],mt_filt1.col.Super_Population_Classification])

:
p = hl.plot.qq(gwas_linear2.linreg.p_value)
show(p)

# %%
## MANHATTAN PLOT
from bokeh.plotting import figure, output_file, show

filtered = gwas_linear2.filter_rows(gwas_linear2.row.logreg.p_value < .005, keep = True)

#filtered.count()
x = hl.plot.manhattan(filtered.row.logreg.p_value, locus=filtered.row.locus, title="Practice", size=4, hover_fields=None)
show(x)
